# %% [markdown]
# #### Търсене и извличане на информация. Приложение на дълбоко машинно обучение
# #### Стоян Михов
# #### Зимен семестър 2025/2026
#
#
# ### Упражнение 2
#
# За да работи програмата трябва да се свали корпус от публицистични текстове за Югоизточна Европа,
#
# предоставен за некомерсиално ползване от Института за български език - БАН
#
# Корпусът може да бъде свален от:
#
# http://dcl.bas.bg/BulNC-registration/#feeds/page/2
#
# От тази страница трябва да свалите:
#
# Корпус с новини
#
# Корпус от публицистични текстове за Югоизточна Европа.
#
# 27.07.2012 Български
#
# 35337  7.9M
#
# Архивът трябва да се разархивира в директорията, в която е програмата.
#
# Преди да се стартира програмата на питон е необходимо да се активира съответното обкръжение с командата:
#
# ```
# conda activate tii
# ```

# %%
import nltk
from nltk.corpus import PlaintextCorpusReader
import sys
import math

# %%
corpus_root = '../JOURNALISM.BG/C-MassMedia'
myCorpus = PlaintextCorpusReader(corpus_root, '.*\.txt')
fileNames = myCorpus.fileids()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# /var/folders/ch/g64kqcy51rj6nx1pxtf5tcdc0000gn/T/ipykernel_26328/638221215.py:2: SyntaxWarning: invalid escape sequence '\.'
#   myCorpus = PlaintextCorpusReader(corpus_root, '.*\.txt')

# %%
fileNames
# Out:
# ['C-Culture/00004923nCCL.txt',
#  'C-Culture/00005005nCCL.txt',
#  'C-Culture/00005063nCCL.txt',
#  'C-Culture/00005123nCCL.txt',
#  'C-Culture/00005190nCCL.txt',
#  'C-Culture/00005282nCCL.txt',
#  'C-Culture/00005338nCCL.txt',
#  'C-Culture/00005407nCCL.txt',
#  'C-Culture/00005474nCCL.txt',
#  'C-Culture/00005581nCCL.txt',
#  'C-Culture/00005663nCCL.txt',
#  'C-Culture/00005724nCCL.txt',
#  'C-Culture/00005795nCCL.txt',
#  'C-Culture/00005882nCCL.txt',
#  'C-Culture/00005942nCCL.txt',
#  'C-Culture/00006016nCCL.txt',
#  'C-Culture/00006087nCCL.txt',
#  'C-Culture/00006165nCCL.txt',
#  'C-Culture/00006239nCCL.txt',
#  'C-Culture/00006312nCCL.txt',
#  'C-Culture/00006381nCCL.txt',
#  'C-Culture/00006460nCCL.txt',
#  'C-Culture/00006530nCCL.txt',
#  'C-Culture/00006605nCCL.txt',
#  'C-Culture/00006693nCCL.txt',
#  'C-Culture/00006741nCCL.txt',
#  'C-Culture/00006772nCCL.txt',
#  'C-Culture/00006814nCCL.txt',
#  'C-Culture/00006850nCCL.txt',
#  'C-Culture/00006853nCCL.txt',
#  'C-Culture/00006935nCCL.txt',
#  'C-Culture/00007015nCCL.txt',
#  'C-Culture/00007096nCCL.txt',
#  'C-Culture/00007180nCCL.txt',
#  'C-Culture/00007257nCCL.txt',
#  'C-Culture/00007337nCCL.txt',
#  'C-Culture/00007417nCCL.txt',
#  'C-Culture/00007495nCCL.txt',
#  'C-Culture/00007575nCCL.txt',
#  'C-Culture/00007651nCCL.txt',
#  'C-Culture/00007729nCCL.txt',
#  'C-Culture/00007801nCCL.txt',
#  'C-Culture/00007885nCCL.txt',
#  'C-Culture/00007966nCCL.txt',
#  'C-Culture/00008042nCCL.txt',
#  'C-Culture/00008047nCCL.txt',
#  'C-Culture/00008135nCCL.txt',
#  'C-Culture/00008214nCCL.txt',
#  'C-Culture/00008298nCCL.txt',
#  'C-Culture/00008376nCCL.txt',
#  'C-Culture/00008458nCCL.txt',
#  'C-Culture/00008490nCCL.txt',
#  'C-Culture/00008542nCCL.txt',
#  'C-Culture/00008623nCCL.txt',
#  'C-Culture/00008697nCCL.txt',
#  'C-Culture/00008780nCCL.txt',
#  'C-Culture/00008870nCCL.txt',
#  'C-Culture/00008953nCCL.txt',
#  'C-Culture/00008961nCCL.txt',
#  'C-Culture/00009034nCCL.txt',
#  'C-Culture/00009116nCCL.txt',
#  'C-Culture/00009188nCCL.txt',
#  'C-Culture/00009245nCCL.txt',
#  'C-Culture/00009280nCCL.txt',
#  'C-Culture/00009361nCCL.txt',
#  'C-Culture/00009425nCCL.txt',
#  'C-Culture/00009437nCCL.txt',
#  'C-Culture/00009492nCCL.txt',
#  'C-Culture/00009560nCCL.txt',
#  'C-Culture/00009611nCCL.txt',
#  'C-Culture/00009636nCCL.txt',
#  'C-Culture/00009714nCCL.txt',
#  'C-Culture/00009794nCCL.txt',
#  'C-Culture/00009871nCCL.txt',
#  'C-Culture/00009944nCCL.txt',
#  'C-Culture/00010022nCCL.txt',
#  'C-Culture/00010098nCCL.txt',
#  'C-Culture/00010178nCCL.txt',
#  'C-Culture/00010252nCCL.txt',
#  'C-Culture/00010329nCCL.txt',
#  'C-Culture/00010396nCCL.txt',
#  'C-Culture/00010458nCCL.txt',
#  'C-Culture/00010535nCCL.txt',
#  'C-Culture/00010615nCCL.txt',
#  'C-Culture/00010696nCCL.txt',
#  'C-Culture/00010767nCCL.txt',
#  'C-Culture/00010825nCCL.txt',
#  'C-Culture/00010844nCCL.txt',
#  'C-Culture/00010925nCCL.txt',
#  'C-Culture/00011013nCCL.txt',
#  'C-Culture/00011083nCCL.txt',
#  'C-Culture/00011163nCCL.txt',
#  'C-Culture/00011247nCCL.txt',
#  'C-Culture/00011321nCCL.txt',
#  'C-Culture/00011398nCCL.txt',
#  'C-Culture/00011474nCCL.txt',
#  'C-Culture/00011540nCCL.txt',
#  'C-Culture/00011545nCCL.txt',
#  'C-Culture/00011622nCCL.txt',
#  'C-Culture/00011623nCCL.txt',
#  'C-Culture/00011760nCCZ.txt',
#  'C-Culture/00011839nCCZ.txt',
#  'C-Culture/00011920nCCZ.txt',
#  'C-Culture/00011997nCCZ.txt',
#  'C-Culture/00012075nCCZ.txt',
#  'C-Culture/00012149nCCZ.txt',
#  'C-Culture/00012223nCCZ.txt',
#  'C-Culture/00012301nCCZ.txt',
#  'C-Culture/00012377nCCZ.txt',
#  'C-Culture/00012451nCCZ.txt',
#  'C-Culture/00012528nCCZ.txt',
#  'C-Culture/00012606nCCZ.txt',
#  'C-Culture/00012638nCCL.txt',
#  'E-Economy/00006133nCEL.txt',
#  'E-Economy/00006157nCEL.txt',
#  'E-Economy/00006160nCEL.txt',
#  'E-Economy/00006224nCEL.txt',
#  'E-Economy/00006234nCEL.txt',
#  'E-Economy/00006243nCEL.txt',
#  'E-Economy/00006248nCEL.txt',
#  'E-Economy/00006279nCEL.txt',
#  'E-Economy/00006481nCEL.txt',
#  'E-Economy/00006534nCEL.txt',
#  'E-Economy/00006554nCEL.txt',
#  'E-Economy/00006597nCEL.txt',
#  'E-Economy/00006599nCEL.txt',
#  'E-Economy/00006634nCEL.txt',
#  'E-Economy/00006645nCEL.txt',
#  'E-Economy/00006648nCEL.txt',
#  'E-Economy/00006655nCEL.txt',
#  'E-Economy/00006657nCEL.txt',
#  'E-Economy/00006692nCEL.txt',
#  'E-Economy/00006704nCEL.txt',
#  'E-Economy/00006715nCEL.txt',
#  'E-Economy/00006717nCEL.txt',
#  'E-Economy/00006800nCEL.txt',
#  'E-Economy/00006818nCEL.txt',
#  'E-Economy/00006863nCEL.txt',
#  'E-Economy/00006880nCEL.txt',
#  'E-Economy/00006916nCEL.txt',
#  'E-Economy/00006926nCEL.txt',
#  'E-Economy/00006963nCEL.txt',
#  'E-Economy/00007041nCEL.txt',
#  'E-Economy/00007127nCEL.txt',
#  'E-Economy/00007143nCEL.txt',
#  'E-Economy/00007151nCEL.txt',
#  'E-Economy/00007176nCEL.txt',
#  'E-Economy/00007194nCEL.txt',
#  'E-Economy/00007195nCEL.txt',
#  'E-Economy/00007208nCEL.txt',
#  'E-Economy/00007285nCEL.txt',
#  'E-Economy/00007329nCEL.txt',
#  'E-Economy/00007365nCEL.txt',
#  'E-Economy/00007393nCEL.txt',
#  'E-Economy/00007404nCEL.txt',
#  'E-Economy/00007441nCEL.txt',
#  'E-Economy/00007518nCEL.txt',
#  'E-Economy/00007520nCEL.txt',
#  'E-Economy/00007567nCEL.txt',
#  'E-Economy/00007568nCEL.txt',
#  'E-Economy/00007601nCEL.txt',
#  'E-Economy/00007616nCEL.txt',
#  'E-Economy/00007646nCEL.txt',
#  'E-Economy/00007676nCEL.txt',
#  'E-Economy/00007709nCEL.txt',
#  'E-Economy/00007738nCEL.txt',
#  'E-Economy/00007754nCEL.txt',
#  'E-Economy/00007770nCEL.txt',
#  'E-Economy/00007819nCEL.txt',
#  'E-Economy/00007831nCEL.txt',
#  'E-Economy/00007903nCEL.txt',
#  'E-Economy/00007911nCEL.txt',
#  'E-Economy/00007927nCEL.txt',
#  'E-Economy/00007932nCEL.txt',
#  'E-Economy/00007959nCEL.txt',
#  'E-Economy/00007985nCEL.txt',
#  'E-Economy/00007988nCEL.txt',
#  'E-Economy/00008024nCEL.txt',
#  'E-Economy/00008101nCEL.txt',
#  'E-Economy/00008107nCEL.txt',
#  'E-Economy/00008262nCEL.txt',
#  'E-Economy/00008271nCEL.txt',
#  'E-Economy/00008277nCEL.txt',
#  'E-Economy/00008349nCEL.txt',
#  'E-Economy/00008363nCEL.txt',
#  'E-Economy/00008392nCEL.txt',
#  'E-Economy/00008397nCEL.txt',
#  'E-Economy/00008415nCEL.txt',
#  'E-Economy/00008449nCEL.txt',
#  'E-Economy/00008455nCEL.txt',
#  'E-Economy/00008580nCEL.txt',
#  'E-Economy/00008593nCEL.txt',
#  'E-Economy/00008594nCEL.txt',
#  'E-Economy/00008637nCEL.txt',
#  'E-Economy/00008641nCEL.txt',
#  'E-Economy/00008716nCEL.txt',
#  'E-Economy/00008727nCEL.txt',
#  'E-Economy/00008752nCEL.txt',
#  'E-Economy/00008835nCEL.txt',
#  'E-Economy/00008841nCEL.txt',
#  'E-Economy/00008890nCEL.txt',
#  'E-Economy/00008913nCEL.txt',
#  'E-Economy/00008950nCEL.txt',
#  'E-Economy/00008956nCEL.txt',
#  'E-Economy/00009019nCEL.txt',
#  'E-Economy/00009038nCEL.txt',
#  'E-Economy/00009433nCEL.txt',
#  'E-Economy/00009471nCEL.txt',
#  'E-Economy/00009516nCEL.txt',
#  'E-Economy/00009570nCEL.txt',
#  'E-Economy/00009580nCEL.txt',
#  'E-Economy/00009660nCEL.txt',
#  'E-Economy/00009670nCEL.txt',
#  'E-Economy/00009713nCEL.txt',
#  'E-Economy/00009729nCEL.txt',
#  'E-Economy/00009830nCEL.txt',
#  'E-Economy/00009843nCEL.txt',
#  'E-Economy/00009883nCEL.txt',
#  'E-Economy/00009896nCEL.txt',
#  'E-Economy/00009955nCEL.txt',
#  'E-Economy/00009992nCEL.txt',
#  'E-Economy/00010104nCEL.txt',
#  'E-Economy/00010153nCEL.txt',
#  'E-Economy/00010200nCEL.txt',
#  'E-Economy/00010227nCEL.txt',
#  'E-Economy/00010323nCEL.txt',
#  'E-Economy/00010342nCEL.txt',
#  'E-Economy/00010411nCEL.txt',
#  'E-Economy/00010531nCEL.txt',
#  'E-Economy/00010591nCEL.txt',
#  'E-Economy/00010607nCEL.txt',
#  'E-Economy/00010643nCEL.txt',
#  'E-Economy/00010683nCEL.txt',
#  'E-Economy/00010684nCEL.txt',
#  'E-Economy/00010699nCEL.txt',
#  'E-Economy/00010728nCEL.txt',
#  'E-Economy/00010771nCEL.txt',
#  'E-Economy/00010816nCEL.txt',
#  'E-Economy/00010828nCEL.txt',
#  'E-Economy/00010856nCEL.txt',
#  'E-Economy/00010866nCEL.txt',
#  'E-Economy/00010867nCEL.txt',
#  'E-Economy/00010878nCEL.txt',
#  'E-Economy/00010905nCEL.txt',
#  'E-Economy/00010944nCEL.txt',
#  'E-Economy/00010990nCEL.txt',
#  'E-Economy/00011118nCEL.txt',
#  'E-Economy/00011166nCEL.txt',
#  'E-Economy/00011195nCEL.txt',
#  'E-Economy/00011196nCEL.txt',
#  'E-Economy/00011214nCEL.txt',
#  'E-Economy/00011329nCEL.txt',
#  'E-Economy/00011377nCEL.txt',
#  'E-Economy/00011403nCEL.txt',
#  'E-Economy/00011423nCEL.txt',
#  'E-Economy/00011558nCEL.txt',
#  'E-Economy/00011561nCEL.txt',
#  'E-Economy/00011593nCEL.txt',
#  'E-Economy/00011627nCEL.txt',
#  'E-Economy/00011776nCEA.txt',
#  'E-Economy/00011866nCEL.txt',
#  'E-Economy/00011909nCEA.txt',
#  'E-Economy/00011963nCEL.txt',
#  'E-Economy/00012009nCEL.txt',
#  'E-Economy/00012033nCEL.txt',
#  'E-Economy/00012036nCEA.txt',
#  'E-Economy/00012047nCEB.txt',
#  'E-Economy/00012048nCEA.txt',
#  'E-Economy/00012059nCEL.txt',
#  'E-Economy/00012069nCEL.txt',
#  'E-Economy/00012123nCEB.txt',
#  'E-Economy/00012161nCEL.txt',
#  'E-Economy/00012244nCEL.txt',
#  'E-Economy/00012248nCEL.txt',
#  'E-Economy/00012276nCEA.txt',
#  'E-Economy/00012380nCEA.txt',
#  'E-Economy/00012392nCEA.txt',
#  'E-Economy/00012401nCEL.txt',
#  'E-Economy/00012485nCEL.txt',
#  'E-Economy/00012504nCEA.txt',
#  'E-Economy/00012525nCEL.txt',
#  'E-Economy/00012682nCEL.txt',
#  'E-Economy/00012684nCEL.txt',
#  'E-Economy/00012690nCEL.txt',
#  'E-Economy/00012732nCEL.txt',
#  'E-Economy/00012847nCEL.txt',
#  'E-Economy/00012990nCEA.txt',
#  'E-Economy/00012997nCEL.txt',
#  'E-Economy/00013046nCEL.txt',
#  'E-Economy/00013056nCEL.txt',
#  'E-Economy/00013067nCEL.txt',
#  'E-Economy/00013072nCEL.txt',
#  'E-Economy/00013095nCEB.txt',
#  'E-Economy/00013107nCEL.txt',
#  'E-Economy/00013148nCEA.txt',
#  'E-Economy/00013248nCEL.txt',
#  'E-Economy/00013273nCEA.txt',
#  'E-Economy/00013288nCEA.txt',
#  'E-Economy/00013299nCEA.txt',
#  'E-Economy/00013489nCEL.txt',
#  'E-Economy/00013588nCEL.txt',
#  'E-Economy/00013625nCEL.txt',
#  'E-Economy/00013632nCEA.txt',
#  'E-Economy/00013654nCEA.txt',
#  'E-Economy/00013748nCEL.txt',
#  'E-Economy/00013806nCEL.txt',
#  'E-Economy/00013827nCEA.txt',
#  'E-Economy/00013847nCEL.txt',
#  'E-Economy/00013883nCEL.txt',
#  'E-Economy/00013899nCEA.txt',
#  'E-Economy/00013966nCEL.txt',
#  'E-Economy/00014034nCEL.txt',
#  'E-Economy/00014085nCEL.txt',
#  'E-Economy/00014153nCEA.txt',
#  'E-Economy/00014223nCEL.txt',
#  'E-Economy/00014293nCEA.txt',
#  'E-Economy/00014320nCEL.txt',
#  'E-Economy/00014438nCEL.txt',
#  'E-Economy/00014446nCEL.txt',
#  'E-Economy/00014477nCEL.txt',
#  'E-Economy/00014479nCEL.txt',
#  'E-Economy/00014515nCEL.txt',
#  'E-Economy/00014677nCEA.txt',
#  'E-Economy/00014716nCEL.txt',
#  'E-Economy/00014800nCEL.txt',
#  'E-Economy/00014834nCEL.txt',
#  'E-Economy/00014836nCEA.txt',
#  'E-Economy/00014887nCEL.txt',
#  'E-Economy/00014911nCEL.txt',
#  'E-Economy/00014979nCEB.txt',
#  'E-Economy/00014988nCEL.txt',
#  'E-Economy/00015045nCEL.txt',
#  'E-Economy/00015072nCEL.txt',
#  'E-Economy/00015115nCEL.txt',
#  'E-Economy/00015193nCEL.txt',
#  'E-Economy/00015462nCEL.txt',
#  'E-Economy/00015500nCEL.txt',
#  'E-Economy/00015597nCEL.txt',
#  'E-Economy/00015610nCEL.txt',
#  'E-Economy/00015624nCEL.txt',
#  'E-Economy/00015776nCEL.txt',
#  'E-Economy/00015812nCEL.txt',
#  'E-Economy/00015839nCEL.txt',
#  'E-Economy/00016078nCEA.txt',
#  'E-Economy/00016151nCEL.txt',
#  'E-Economy/00016239nCEL.txt',
#  'E-Economy/00016242nCEA.txt',
#  'E-Economy/00016281nCEA.txt',
#  'E-Economy/00016325nCEA.txt',
#  'E-Economy/00016368nCEB.txt',
#  'E-Economy/00016438nCEL.txt',
#  'E-Economy/00016460nCEL.txt',
#  'E-Economy/00016477nCEA.txt',
#  'E-Economy/00016607nCEL.txt',
#  'E-Economy/00016611nCEA.txt',
#  'E-Economy/00016649nCEL.txt',
#  'E-Economy/00016698nCEL.txt',
#  'E-Economy/00016774nCEL.txt',
#  'E-Economy/00016790nCEL.txt',
#  'E-Economy/00016855nCEL.txt',
#  'E-Economy/00016866nCEL.txt',
#  'E-Economy/00016871nCEL.txt',
#  'E-Economy/00016879nCEL.txt',
#  'E-Economy/00016984nCEL.txt',
#  'E-Economy/00017133nCEA.txt',
#  'E-Economy/00017207nCEL.txt',
#  'E-Economy/00017214nCEA.txt',
#  'E-Economy/00017216nCEL.txt',
#  'E-Economy/00017226nCEA.txt',
#  'E-Economy/00017241nCEL.txt',
#  'E-Economy/00017268nCEL.txt',
#  'E-Economy/00017275nCEL.txt',
#  'E-Economy/00017300nCEL.txt',
#  'E-Economy/00017342nCEL.txt',
#  'E-Economy/00017343nCEB.txt',
#  'E-Economy/00017371nCEA.txt',
#  'E-Economy/00017506nCEL.txt',
#  'E-Economy/00017643nCEL.txt',
#  'E-Economy/00017679nCEL.txt',
#  'E-Economy/00017695nCEL.txt',
#  'E-Economy/00017828nCEA.txt',
#  'E-Economy/00017893nCEB.txt',
#  'E-Economy/00017905nCEL.txt',
#  'E-Economy/00017934nCEL.txt',
#  'E-Economy/00018000nCEA.txt',
#  'E-Economy/00018055nCEL.txt',
#  'E-Economy/00018160nCEL.txt',
#  'E-Economy/00018170nCEL.txt',
#  'E-Economy/00018275nCEA.txt',
#  'E-Economy/00018288nCEA.txt',
#  'E-Economy/00018355nCEL.txt',
#  'E-Economy/00018426nCEB.txt',
#  'E-Economy/00018569nCEL.txt',
#  'E-Economy/00018799nCEL.txt',
#  'E-Economy/00018810nCEL.txt',
#  'E-Economy/00018842nCEL.txt',
#  'E-Economy/00018859nCEA.txt',
#  'E-Economy/00018883nCEZ.txt',
#  'E-Economy/00018923nCEA.txt',
#  'E-Economy/00018957nCEL.txt',
#  'E-Economy/00019075nCEL.txt',
#  'E-Economy/00019170nCEL.txt',
#  'E-Economy/00019206nCEL.txt',
#  'E-Economy/00019219nCEL.txt',
#  'E-Economy/00019365nCEL.txt',
#  'E-Economy/00019418nCEZ.txt',
#  'E-Economy/00019440nCEL.txt',
#  'E-Economy/00019561nCEL.txt',
#  'E-Economy/00019572nCEL.txt',
#  'E-Economy/00019584nCEL.txt',
#  'E-Economy/00019611nCEA.txt',
#  'E-Economy/00019722nCEL.txt',
#  'E-Economy/00019805nCEZ.txt',
#  'E-Economy/00019824nCEL.txt',
#  'E-Economy/00019972nCEA.txt',
#  'E-Economy/00020063nCEL.txt',
#  'E-Economy/00020395nCEL.txt',
#  'E-Economy/00020457nCEB.txt',
#  'E-Economy/00020534nCEB.txt',
#  'E-Economy/00020551nCEA.txt',
#  'E-Economy/00020617nCEB.txt',
#  'E-Economy/00020636nCEA.txt',
#  'E-Economy/00020741nCEL.txt',
#  'E-Economy/00020754nCEZ.txt',
#  'E-Economy/00020922nCEL.txt',
#  'E-Economy/00021012nCEB.txt',
#  'E-Economy/00021057nCEL.txt',
#  'E-Economy/00021091nCEA.txt',
#  'E-Economy/00021188nCEL.txt',
#  'E-Economy/00021237nCEL.txt',
#  'E-Economy/00021358nCEL.txt',
#  'E-Economy/00021419nCEB.txt',
#  'E-Economy/00021548nCEZ.txt',
#  'E-Economy/00021643nCEB.txt',
#  'E-Economy/00021695nCEL.txt',
#  'E-Economy/00021763nCEL.txt',
#  'E-Economy/00021782nCEL.txt',
#  'E-Economy/00021885nCEA.txt',
#  'E-Economy/00022096nCEZ.txt',
#  'E-Economy/00022111nCEA.txt',
#  'E-Economy/00022122nCEL.txt',
#  'E-Economy/00022285nCEA.txt',
#  'E-Economy/00022293nCEL.txt',
#  'E-Economy/00022300nCEL.txt',
#  'E-Economy/00022383nCEZ.txt',
#  'E-Economy/00022463nCEL.txt',
#  'E-Economy/00022465nCEL.txt',
#  'E-Economy/00022688nCEZ.txt',
#  'E-Economy/00022761nCEL.txt',
#  'E-Economy/00022768nCEL.txt',
#  'E-Economy/00022921nCEZ.txt',
#  'E-Economy/00022973nCEA.txt',
#  'E-Economy/00023227nCEZ.txt',
#  'E-Economy/00023489nCEA.txt',
#  'E-Economy/00023677nCEL.txt',
#  'E-Economy/00024006nCEL.txt',
#  'E-Economy/00024013nCEA.txt',
#  'E-Economy/00024020nCEL.txt',
#  'E-Economy/00024035nCEL.txt',
#  'E-Economy/00024228nCEB.txt',
#  'E-Economy/00024255nCEL.txt',
#  'E-Economy/00024357nCEL.txt',
#  'E-Economy/00024416nCEL.txt',
#  'E-Economy/00024748nCEB.txt',
#  'E-Economy/00024901nCEL.txt',
#  'E-Economy/00024947nCEL.txt',
#  'E-Economy/00024978nCEL.txt',
#  'E-Economy/00025013nCEL.txt',
#  'E-Economy/00025140nCEL.txt',
#  'E-Economy/00025311nCEL.txt',
#  'E-Economy/00025318nCEL.txt',
#  'E-Economy/00025348nCEL.txt',
#  'E-Economy/00025359nCEB.txt',
#  'E-Economy/00025410nCEL.txt',
#  'E-Economy/00025520nCEL.txt',
#  'E-Economy/00025550nCEL.txt',
#  'E-Economy/00025565nCEZ.txt',
#  'E-Economy/00025581nCEL.txt',
#  'E-Economy/00025747nCEZ.txt',
#  'E-Economy/00025817nCEL.txt',
#  'E-Economy/00026119nCEL.txt',
#  'E-Economy/00026250nCEL.txt',
#  'E-Economy/00026432nCEL.txt',
#  'E-Economy/00026500nCEZ.txt',
#  'E-Economy/00026534nCEL.txt',
#  'E-Economy/00026544nCEL.txt',
#  'E-Economy/00026580nCEL.txt',
#  'E-Economy/00026708nCEL.txt',
#  'E-Economy/00026818nCEA.txt',
#  'E-Economy/00026829nCEA.txt',
#  'E-Economy/00026836nCEL.txt',
#  'E-Economy/00026950nCEL.txt',
#  'E-Economy/00027282nCEA.txt',
#  'E-Economy/00027428nCEL.txt',
#  'E-Economy/00027526nCEB.txt',
#  'E-Economy/00027563nCEL.txt',
#  'E-Economy/00027639nCEL.txt',
#  'E-Economy/00027659nCEL.txt',
#  'E-Economy/00027702nCEA.txt',
#  'E-Economy/00027703nCEA.txt',
#  'E-Economy/00027862nCEL.txt',
#  'E-Economy/00027933nCEL.txt',
#  'E-Economy/00028000nCEA.txt',
#  'E-Economy/00028018nCEL.txt',
#  'E-Economy/00028085nCEL.txt',
#  'E-Economy/00028172nCEZ.txt',
#  'E-Economy/00028206nCEL.txt',
#  'E-Economy/00028390nCEZ.txt',
#  'E-Economy/00028467nCEL.txt',
#  'E-Economy/00028535nCEZ.txt',
#  'E-Economy/00028650nCEL.txt',
#  'E-Economy/00028680nCEZ.txt',
#  'E-Economy/00028783nCEA.txt',
#  'E-Economy/00028825nCEL.txt',
#  'E-Economy/00028882nCEA.txt',
#  'E-Economy/00028961nCEA.txt',
#  'E-Economy/00029033nCEL.txt',
#  'E-Economy/00029097nCEA.txt',
#  'E-Economy/00029193nCEA.txt',
#  'E-Economy/00029345nCEL.txt',
#  'E-Economy/00029348nCEL.txt',
#  'E-Economy/00029451nCEZ.txt',
#  'E-Economy/00029546nCEL.txt',
#  'E-Economy/00029588nCEA.txt',
#  'E-Economy/00029817nCEL.txt',
#  'E-Economy/00029828nCEL.txt',
#  'E-Economy/00029856nCEA.txt',
#  'E-Economy/00029866nCEZ.txt',
#  'E-Economy/00029878nCEL.txt',
#  'E-Economy/00029982nCEL.txt',
#  'E-Economy/00030140nCEA.txt',
#  'E-Economy/00030153nCEA.txt',
#  'E-Economy/00030166nCEA.txt',
#  'E-Economy/00030177nCEA.txt',
#  'E-Economy/00030229nCEL.txt',
#  'E-Economy/00030262nCEL.txt',
#  'E-Economy/00030269nCEA.txt',
#  'E-Economy/00030281nCEZ.txt',
#  'E-Economy/00030338nCEL.txt',
#  'E-Economy/00030392nCEZ.txt',
#  'E-Economy/00030410nCEL.txt',
#  'E-Economy/00030469nCEA.txt',
#  'E-Economy/00030505nCEL.txt',
#  'E-Economy/00030768nCEL.txt',
#  'E-Economy/00030792nCEA.txt',
#  'E-Economy/00030834nCEL.txt',
#  'E-Economy/00030857nCEA.txt',
#  'E-Economy/00030895nCEL.txt',
#  'E-Economy/00030982nCEA.txt',
#  'E-Economy/00031048nCEZ.txt',
#  'E-Economy/00031072nCEB.txt',
#  'E-Economy/00031105nCEL.txt',
#  'E-Economy/00031110nCEL.txt',
#  'E-Economy/00031230nCEB.txt',
#  'E-Economy/00031232nCEA.txt',
#  'E-Economy/00031248nCEL.txt',
#  'E-Economy/00031267nCEL.txt',
#  'E-Economy/00031291nCEL.txt',
#  'E-Economy/00031332nCEZ.txt',
#  'E-Economy/00031340nCEL.txt',
#  'E-Economy/00031349nCEA.txt',
#  'E-Economy/00031352nCEL.txt',
#  'E-Economy/00031370nCEL.txt',
#  'E-Economy/00031371nCEL.txt',
#  'E-Economy/00031433nCEL.txt',
#  'E-Economy/00031453nCEZ.txt',
#  'E-Economy/00031468nCEL.txt',
#  'E-Economy/00031612nCEZ.txt',
#  'E-Economy/00031787nCEL.txt',
#  'E-Economy/00031846nCEL.txt',
#  'E-Economy/00031853nCEL.txt',
#  'E-Economy/00031868nCEA.txt',
#  'E-Economy/00031900nCEL.txt',
#  'E-Economy/00031915nCEL.txt',
#  'E-Economy/00031937nCEZ.txt',
#  'E-Economy/00031964nCEA.txt',
#  'E-Economy/00031974nCEL.txt',
#  'E-Economy/00032025nCEL.txt',
#  'E-Economy/00032140nCEL.txt',
#  'E-Economy/00032144nCEA.txt',
#  'E-Economy/00032211nCEB.txt',
#  'E-Economy/00032213nCEA.txt',
#  'E-Economy/00032370nCEL.txt',
#  'E-Economy/00032448nCEZ.txt',
#  'E-Economy/00032545nCEA.txt',
#  'E-Economy/00032733nCEL.txt',
#  'E-Economy/00032754nCEL.txt',
#  ...]

# %%
def printDocuments(myCorpus,fileNames,docIDs):
    for docID in docIDs:
        text = myCorpus.words(fileNames[docID])
        print('Document ID: '+str(docID))
        for word in text:
            print(word,end=' ')
        print('\n')

# %%
printDocuments(myCorpus,fileNames,[0, 1, 10])

# %%
class progressBar:
    def __init__(self, barWidth=80):
        self.barWidth = barWidth
        self.period = None

    def start(self, count):
        self.period = int(count / self.barWidth)
        sys.stdout.write("["+(" " * self.barWidth)+"]\n")
        sys.stdout.flush()
        sys.stdout.write("[") # for jupyter
        sys.stdout.flush() # for jupyter
        # sys.stdout.write("\b" * (self.barWidth+1)) # for terminal

    def tick(self, item):
        if (item+1) % self.period == 0:
            sys.stdout.write("-")
            sys.stdout.flush()

    def stop(self):
        sys.stdout.write("]\n")

# %%
pb = progressBar()
pb.start(len(fileNames))
dictionary={}
for docID, fileName in enumerate(fileNames):
    pb.tick(docID)
    text = myCorpus.words(fileName)
    for token in text:
        if not token.isalpha(): continue
        term = token.lower()
        if term in dictionary:
            postings = dictionary[term]
            if postings[-1] < docID:
                postings.append(docID)
        else:
            dictionary[term] = [docID]
pb.stop()

# %%
def intersect(p1,p2):
    i1=0
    i2=0
    answer=[]
    while i1<len(p1) and i2<len(p2):
        if p1[i1] == p2[i2]:
            answer.append(p1[i1])
            i1 += 1
            i2 += 1
        elif p1[i1] < p2[i2]:
            i1 += 1
        else:
            i2 += 1
    return answer

# %%
def intersectLists(andLists):
    if not andLists: return []
    postingLists = sorted(andLists, key = lambda x : len(x))
    answer = postingLists[0]
    for i in range(1,len(postingLists)):
        answer = intersect(answer,postingLists[i])
    return answer

# %%
def andSearch(dictionary, termList):
    dicItems = [ dictionary[term] for term in termList if term in dictionary ]
    return intersectLists(dicItems)

# %%
printDocuments(myCorpus, fileNames, andSearch(dictionary, ['културен','обмен','театър']))

# %%
def union(p1,p2):
    i1 = 0
    i2 = 0
    answer = []
    while i1 < len(p1) or i2 < len(p2):
        if i2 == len(p2) or (i1 < len(p1) and p1[i1] < p2[i2]):
            answer.append(p1[i1])
            i1 += 1
        elif i1 == len(p1) or (i2 < len(p2) and p2[i2] < p1[i1]):
            answer.append(p2[i2])
            i2 += 1
        else:
            answer.append(p1[i1])
            i1 += 1
            i2 += 1
    return answer

# %%
class Trie:
    def __init__(self):
        self.stateTransitions = [{}]
        self.finalStates = set()

    def traverse(self,word,initialState = 0):
        s = initialState
        i = 0
        while i < len(word) and word[i] in self.stateTransitions[s]:
            s = self.stateTransitions[s][word[i]]
            i += 1
        return s, i

    def isFinal(self, s):
        return s in self.finalStates

    def inTrie(self, word):
        s, i = self.traverse(word)
        return i == len(word) and self.isFinal(s)

    def addWord(self,word):
        s, i = self.traverse(word)
        while i < len(word):
            newState = len(self.stateTransitions)
            self.stateTransitions.append({})
            st = self.stateTransitions[s]
            st[word[i]] = newState
            s = newState
            i += 1
        self.finalStates.add(s)

    def getWordsFromState(self,s):
        answer = []
        if s in self.finalStates:
            answer.append('')
        st = self.stateTransitions[s]
        for (char,nextstate) in st.items():
            answer += [ char + word for word in self.getWordsFromState(nextstate) ]
        return answer

    def getWordsWithPrefix(self,prefix):
        s,i = self.traverse(prefix)
        if i != len(prefix):
            return []
        else:
            return [ prefix + word for word in self.getWordsFromState(s) ]

# %%
dictionaryTrie=Trie()
for term in list(dictionary):
    dictionaryTrie.addWord(term)

# %%
dictionaryTrie.getWordsWithPrefix('теат')

# %%
def andSearchWithWildCards(dictionary,dictionaryTrie,patternList):
    items = []
    for pattern in patternList:
        orList = []
        for term in dictionaryTrie.getWordsWithPrefix(pattern):
            orList = union(orList,dictionary[term])
        items.append(orList)
    return intersectLists(items)

# %%
result = andSearchWithWildCards(dictionary, dictionaryTrie, ['култур','обмен','теат'])
printDocuments(myCorpus, fileNames, result)
